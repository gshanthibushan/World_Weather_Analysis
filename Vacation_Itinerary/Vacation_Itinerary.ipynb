# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0        6    Puerto Ayora      EC     80.60    scattered clouds  -0.7393
# 1        8        Cidreira      BR     88.30           clear sky -30.1811
# 2       13          Atuona      PF     80.49    scattered clouds  -9.8000
# 3       15         Rikitea      PF     78.24          light rain -23.1203
# 4       17  Saint-Philippe      RE     78.80          light rain -21.3585
#
#         Lng                    Hotel Name
# 0  -90.3518     Finch Bay Galapagos Hotel
# 1  -50.2056                 Hotel Castelo
# 2 -139.0333                   Villa Enata
# 3 -134.9692                Pension Maro'i
# 4   55.7679  Chambres d'hôte "La Trinité"

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
description= vacation_df["Current Description"]
fig= gmaps.figure(center=(30,31), zoom_level= 1.5)
heat_layer=gmaps.heatmap_layer(locations, dissipating= False, max_intensity=300, point_radius=4)
marker_layer=gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
BR_itinerary_df = vacation_df.loc[(vacation_df['Country'] =='BR')]
BR_itinerary_df
# Out:
#      City_ID                  City Country  Max Temp Current Description  \
# 1          8              Cidreira      BR     88.30           clear sky
# 23        69            Vila Velha      BR     84.20           clear sky
# 28        98       Arraial Do Cabo      BR     87.80           clear sky
# 31       102            Esmeraldas      BR     82.40           clear sky
# 33       105                Castro      BR     79.92           clear sky
# 35       115                Touros      BR     86.00    scattered clouds
# 53       161     Sao Joao Da Barra      BR     87.80          few clouds
# 58       175         Miguel Calmon      BR     88.45       broken clouds
# 60       185            Rio Grande      BR     80.60    scattered clouds
# 63       192                 Amapa      BR     80.55     overcast clouds
# 66       195              Maragogi      BR     81.32       moderate rain
# 67       196               Manaira      BR     78.87       broken clouds
# 72       208              Paracuru      BR     78.80       broken clouds
# 74       219                Acarau      BR     84.78       moderate rain
# 81       240    Sao Felix Do Xingu      BR     89.42     overcast clouds
# 82       248              Cururupu      BR     85.50       moderate rain
# 85       258                 Maraa      BR     77.56       moderate rain
# 86       259                Maceio      BR     75.20                mist
# 93       276  Vitoria Da Conquista      BR     81.57       broken clouds
# 96       298           Santa Maria      BR     75.20       broken clouds
# 103      323                Pocoes      BR     78.10       broken clouds
# 108      334           Sidrolandia      BR     89.60       broken clouds
# 122      376                Nazare      BR     84.11     overcast clouds
# 123      378      Sao Joao Del Rei      BR     78.80           clear sky
# 124      379            Carutapera      BR     81.73     overcast clouds
# 133      404            Correntina      BR     89.01     overcast clouds
# 148      464     Placido De Castro      BR     85.48       broken clouds
# 176      544         Alta Floresta      BR     89.60       broken clouds
# 177      545               Urucara      BR     84.85     overcast clouds
# 189      581                Bayeux      BR     80.60       broken clouds
# 191      584              Bocaiuva      BR     84.20           clear sky
# 193      589                Uarini      BR     75.20       moderate rain
# 201      609              Cabedelo      BR     80.60          light rain
# 209      636              Ilhabela      BR     81.61           clear sky
#
#          Lat      Lng                                Hotel Name
# 1   -30.1811 -50.2056                             Hotel Castelo
# 23  -20.3297 -40.2925                 Quality Suites Vila Velha
# 28  -22.9661 -42.0278                       Pousada Porto Praia
# 31  -19.7625 -44.3139                Forasteiro Pousada - Hotel
# 33  -24.7911 -50.0119                            CHACARA BAILLY
# 35   -5.1989 -35.4608                           INN NEW HORIZON
# 53  -21.6403 -41.0511                   Pousada Porto De Canoas
# 58  -11.4289 -40.5950                           Pousada Guiomar
# 60  -32.0350 -52.0986                Hotel Atlântico Rio Grande
# 63    1.0000 -52.0000                                       NaN
# 66   -9.0122 -35.2225  Salinas do Maragogi All Inclusive Resort
# 67   -7.7061 -38.1544                             Pousada Irerê
# 72   -3.4100 -39.0306                        Hotel Vento Brasil
# 74   -2.8856 -40.1200                          castelo pizzaria
# 81   -6.6447 -51.9950                         Rio Xingu Camping
# 82   -1.8283 -44.8683                        Pousada Través'cia
# 85   -1.8333 -65.3667                                       NaN
# 86   -9.6658 -35.7353                            Poutur Pousada
# 93  -14.8661 -40.8394                            Hotel Universo
# 96  -29.6842 -53.8069                             Hotel Morotin
# 103 -14.5297 -40.3653                       Poções Palace Hotel
# 108 -20.9319 -54.9614                     Agropet São Francisco
# 122 -13.0350 -39.0144                          Pousada da Fonte
# 123 -21.1356 -44.2617                              Solara Hotel
# 124  -1.1950 -46.0200                                    Lidera
# 133 -13.3433 -44.6367                  Hotel Pousada dos Sonhos
# 148 -10.3353 -67.1856                             Hotel Carioca
# 176  -9.8756 -56.0861                  Floresta Amazonica Hotel
# 177  -2.5364 -57.7600                                Hotel japa
# 189  -7.1250 -34.9322                            Infinity Motel
# 191 -17.1078 -43.8150                             Hotel Maxim's
# 193  -2.9900 -65.1083                                       NaN
# 201  -6.9811 -34.8339                             Hotel Pigalle
# 209 -23.7781 -45.3581                           Ilha Flat Hotel

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"]=="Rio Grande")]
vacation_end = vacation_df.loc[(vacation_df["City"]== "Rio Grande")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"]=="Paracuru")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"]=="Vitoria Da Conquista")] 
vacation_stop3 = vacation_df.loc[(vacation_df["City"]== "Ilhabela")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start.iloc[:,5:7].to_numpy()
end = vacation_end.iloc[:,5:7].to_numpy()
stop1= vacation_stop1.iloc[:,5:7].to_numpy()
stop2=vacation_stop2.iloc[:,5:7].to_numpy()
stop3= vacation_stop3.iloc[:,5:7].to_numpy()

start
# Out:
# array([[-32.035 , -52.0986]])

# %%
# create a list of tuple of 4 cities' coordinate.
gmaps.configure(api_key = g_key)
four_cities_df = vacation_df.loc[[60,72,93,209],:]
four_cities_df
BR_coord_list = list(zip(four_cities_df['Lat'], four_cities_df['Lng']))
BR_coord_list
# Out:
# [(-32.035, -52.0986),
#  (-3.41, -39.0306),
#  (-14.8661, -40.8394),
#  (-23.7781, -45.3581)]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
BR_route = gmaps.directions_layer(BR_coord_list[0], BR_coord_list[-1], waypoints=[BR_coord_list[1],BR_coord_list[2],],
                                  travel_mode='DRIVING')
fig.add_layer(BR_route)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, 
                          vacation_stop2, vacation_stop3]
                         ,ignore_index=True)
itinerary_df
# Out:
#    City_ID                  City Country  Max Temp Current Description  \
# 0      185            Rio Grande      BR     80.60    scattered clouds
# 1      208              Paracuru      BR     78.80       broken clouds
# 2      276  Vitoria Da Conquista      BR     81.57       broken clouds
# 3      636              Ilhabela      BR     81.61           clear sky
#
#        Lat      Lng                  Hotel Name
# 0 -32.0350 -52.0986  Hotel Atlântico Rio Grande
# 1  -3.4100 -39.0306          Hotel Vento Brasil
# 2 -14.8661 -40.8394              Hotel Universo
# 3 -23.7781 -45.3581             Ilha Flat Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
description= vacation_df["Current Description"]
fig= gmaps.figure(center=(-32,-31), zoom_level= 5)
heat_layer=gmaps.heatmap_layer(locations, dissipating= False, max_intensity=300, point_radius=4)
marker_layer=gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
